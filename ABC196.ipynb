# %% [markdown]
# https://atcoder.jp/contests/abc196

# %%
# 問題A
a,b = map(int,input().split())
c,d = map(int,input().split())

print(b-c)
# Out:
# 200

# %%
# 問題B
X = input()

L = len(X) if len(X) <= 102 else 102

ans = X
for i in range(1,L):
    if X[-i] == '.':
        ans = X[:-i]
        break
    else:
        ans = ans

print(ans)
# Out:
# 5

# %%
# 問題C
N = int(input())
for i in range(1, 1000001):
    if int(str(i) * 2) > N:
        print(i - 1)
        exit()
# Out:
# 663329
# 663330
# 663331
# 663332
# 663333
# 663334
# 663335
# 663336
# 663337
# 663338
# 663339
# 663340
# 663341
# 663342
# 663343
# 663344
# 663345
# 663346
# 663347
# 663348
# 663349
# 663350
# 663351
# 663352
# 663353
# 663354
# 663355
# 663356
# 663357
# 663358
# 663359
# 663360
# 663361
# 663362
# 663363
# 663364
# 663365
# 663366
# 663367
# 663368
# 663369
# 663370
# 663371
# 663372
# 663373
# 663374
# 663375
# 663376
# 663377
# 663378
# 663379
# 663380
# 663381
# 663382
# 663383
# 663384
# 663385
# 663386
# 663387
# 663388
# 663389
# 663390
# 663391
# 663392
# 663393
# 663394
# 663395
# 663396
# 663397
# 663398
# 663399
# 663400
# 663401
# 663402
# 663403
# 663404
# 663405
# 663406
# 663407
# 663408
# 663409
# 663410
# 663411
# 663412
# 663413
# 663414
# 663415
# 663416
# 663417
# 663418
# 663419
# 663420
# 663421
# 663422
# 663423
# 663424
# 663425
# 663426
# 663427
# 663428
# 663429
# 663430
# 663431
# 663432
# 663433
# 663434
# 663435
# 663436
# 663437
# 663438
# 663439
# ...
